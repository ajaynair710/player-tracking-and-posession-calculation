# %%
# %pip install ultralytics
# %pip install roboflow
# Out:
# Requirement already satisfied: ultralytics in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (8.3.73)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.1.1)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (3.9.2)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.4.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (0.19.1)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (6.1.0)
# Requirement already satisfied: py-cpuinfo in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.54.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.9.0)
# Requirement already satisfied: setuptools in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (75.1.0)
# Requirement already satisfied: colorama in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: roboflow in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (1.1.53)
# Requirement already satisfied: certifi in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (2024.8.30)
# Requirement already satisfied: idna==3.7 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (1.4.7)
# Requirement already satisfied: matplotlib in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (3.9.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (2.1.1)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (10.4.0)
# Requirement already satisfied: python-dateutil in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (2.2.3)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (4.66.5)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: colorama in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->roboflow) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->roboflow) (4.54.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->roboflow) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->roboflow) (3.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ajayn\appdata\local\programs\python\python312\lib\site-packages (from requests->roboflow) (3.3.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="sZnPwBDRCYyEZYlzUDUe")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from roboflow import Roboflow
#       2 rf = Roboflow(api_key="sZnPwBDRCYyEZYlzUDUe")
#       3 project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
#
# File c:\Users\ajayn\AppData\Local\Programs\Python\Python312\Lib\site-packages\roboflow\__init__.py:13
#      11 from roboflow.adapters import rfapi
#      12 from roboflow.config import API_URL, APP_URL, DEMO_KEYS, load_roboflow_api_key
# ---> 13 from roboflow.core.project import Project
#      14 from roboflow.core.workspace import Workspace
#      15 from roboflow.models import CLIPModel, GazeModel  # noqa: F401
#
# File c:\Users\ajayn\AppData\Local\Programs\Python\Python312\Lib\site-packages\roboflow\core\project.py:16
#      14 from roboflow.adapters.rfapi import ImageUploadError
#      15 from roboflow.config import API_URL, DEMO_KEYS
# ---> 16 from roboflow.core.version import Version
#      17 from roboflow.util.general import Retry
#      18 from roboflow.util.image_utils import load_labelmap
#
# File c:\Users\ajayn\AppData\Local\Programs\Python\Python312\Lib\site-packages\roboflow\core\version.py:12
#       9 from typing import TYPE_CHECKING, Optional, Union
#      11 import requests
# ---> 12 from dotenv import load_dotenv
#      13 from tqdm import tqdm
#      15 from roboflow.config import (
#      16     API_URL,
#      17     APP_URL,
#    (...)
#      25     UNIVERSE_URL,
#      26 )
#
# ImportError: cannot import name 'load_dotenv' from 'dotenv' (c:\Users\ajayn\AppData\Local\Programs\Python\Python312\Lib\site-packages\dotenv\__init__.py)

# %%
dataset.location
# Out:
# '/content/football-players-detection-1'

# %%
import shutil

shutil.move('football-players-detection-1/train',
            'football-players-detection-1/football-players-detection-1/train'
            )

shutil.move('football-players-detection-1/test',
            'football-players-detection-1/football-players-detection-1/test'
            )

shutil.move('football-players-detection-1/valid',
            'football-players-detection-1/football-players-detection-1/valid'
            )
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %%
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
